# %% [markdown]
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# Ссылка на репозиторий: https://github.com/vaultboy324/yandex_git_repo

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ## Как решать задачу

# %% [markdown]
# Продумывать подход к решению этой задачи вам не придётся — руководитель отдела его уже сформировал:
# Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
# Нужно собрать данные по клиентам по следующим группам:
#
# 1) Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#
# 2) Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#
# 3) Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#
# 4) Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# 1) Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#
# 2) В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
#
# 3) Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Данные для работы находятся в нескольких таблицах. Нажмите на название файла, чтобы его скачать.
#
# market_file.csv
#
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# id — номер покупателя в корпоративной базе данных.
#
# Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#
# Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
#
# Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#
# Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#
# Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
#
# Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#
# Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#
# Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
#
# Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#
# Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
#
# Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
#
# Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# market_money.csv
#
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# id — номер покупателя в корпоративной базе данных.
#
# Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#
# Выручка — сумма выручки за период.
#
# market_time.csv
#
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# id — номер покупателя в корпоративной базе данных.
#
# Период — название периода, во время которого зафиксировано общее время.
# минут — значение времени, проведённого на сайте, в минутах.
#
# money.csv
#
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# id — номер покупателя в корпоративной базе данных.
#
# Прибыль — значение прибыли.

# %% [markdown]
# ## Инструкция по выполнению проекта

# %% [markdown]
# Решать задачу вам нужно в два этапа:
#
# Разработайте модель, которая предскажет вероятность снижения покупательской активности.
#
# Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов, но вы также можете выделить свой:
#
#     Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
#
#     Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
#
#     Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
#
#     Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ## Выполнение проекта

# %% [markdown]
# ### Установка библиотек

# %%
# !pip install shap
# !pip install phik

# !pip freeze
# Out:
# ...
# aiobotocore @ file:///C:/b/abs_3cwz1w13nn/croot/aiobotocore_1701291550158/work
# aiohttp @ file:///C:/b/abs_27h_1rpxgd/croot/aiohttp_1707342354614/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# alembic==1.13.3
# altair @ file:///C:/b/abs_27reu1igbg/croot/altair_1687526066495/work
# anaconda-anon-usage @ file:///C:/b/abs_95v3x0wy8p/croot/anaconda-anon-usage_1697038984188/work
# anaconda-catalogs @ file:///C:/b/abs_8btyy0o8s8/croot/anaconda-catalogs_1685727315626/work
# anaconda-client @ file:///C:/b/abs_34txutm0ue/croot/anaconda-client_1708640705294/work
# anaconda-cloud-auth @ file:///C:/b/abs_410afndtyf/croot/anaconda-cloud-auth_1697462767853/work
# anaconda-navigator @ file:///C:/b/abs_b2ftg2likj/croot/anaconda-navigator_1712088050123/work
# ...

# %% [markdown]
# ### Подключение библиотек

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import shap
import phik
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer 

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier

from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import roc_auc_score

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %%
market_file_data = pd.read_csv('datasets/market_file.csv')
market_file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_money_data = pd.read_csv('datasets/market_money.csv')
market_money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time_data = pd.read_csv('datasets/market_time.csv')
market_time_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money_data = pd.read_csv('datasets/money.csv', sep=';')
money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 20.4+ KB

# %% [markdown]
# Названия столбцов совпадают с описанием

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# Необходимо привести все столбцы к единому виду

# %%
def fix_column(column: str) -> str:
    return column.replace(' ', '_').lower()

def make_rename_columns_dict(column_list: list[str]) -> dict:
    result = {}
    for column in column_list:
        result[column] = fix_column(column)
    return result

# %%
market_file_data = market_file_data.rename(
    columns=make_rename_columns_dict(market_file_data.columns)
)
market_file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_money_data = market_money_data.rename(
    columns=make_rename_columns_dict(market_money_data.columns)
)
market_money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time_data = market_time_data.rename(
    columns=make_rename_columns_dict(market_time_data.columns)
)
market_time_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money_data = money_data.rename(
    columns=make_rename_columns_dict(money_data.columns)
)
money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 20.4+ KB

# %% [markdown]
# Теперь все столбцы приведены к единому виду

# %% [markdown]
# В описании таблиц пропусков не наблюдается, можно переходить к удалению дублей

# %%
market_file_data = market_file_data.drop_duplicates()
market_file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_money_data = market_money_data.drop_duplicates()
market_money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time_data = market_time_data.drop_duplicates()
market_time_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money_data = money_data.drop_duplicates()
money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 20.4+ KB

# %% [markdown]
# Поле прибыль имеет тип object, необходимо преобразовать во float

# %%
money_data['прибыль'] = money_data['прибыль'].str.replace(',', '.').astype(float)
money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Для начала необходимо отобрать покупателей с покупательской активностью не менее 3 месяцев. Первым этапом можно проверить записи по таблице money_data, в ней содержится информация о среднемесячной прибыли от покупателя за последние 3 месяца.

# %%
money_data_ids = money_data['id'].unique()
money_data_ids
# Out:
# array([215348, 215349, 215350, ..., 216645, 216646, 216647], dtype=int64)

# %%
market_file_data[market_file_data['id'].isin(money_data_ids)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# В первой таблице все данные попадают под это условие

# %%
market_time_data[market_time_data['id'].isin(money_data_ids)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# Со второй тоже все в порядке

# %%
market_money_data[market_money_data['id'].isin(money_data_ids)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# В третьей таблице также все записи попадают под необходимое условие

# %% [markdown]
# Далее необходимо провести анализ признаков

# %%
def output_numeric(df: pd.DataFrame, column: str) -> None:
    values = df[column].unique()
    if len(values) <= 20 and df[column].dtype == 'int':
        sns.countplot(df[column])
    else:
        plt.hist(df[column])
    plt.grid(True)
    plt.xlabel(column)
    plt.ylabel('Количество')
    plt.title(column)
    plt.show()
    display(df[column].describe())

# %%
def output_categorial(df: pd.DataFrame, column: str) -> None:
    counts = df[column].value_counts()
    plt.pie(
        counts.values,
        labels=counts.keys(),
        autopct='%1.1f%%'
    )
    plt.title(column)
    plt.legend()
    plt.show()

# %%
numeric_columns = money_data.drop(
    columns=['id'], axis=1
).select_dtypes(
    exclude=['object']
).columns

for column in numeric_columns:
    output_numeric(money_data, column)
# Out:
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %%
numeric_columns = market_file_data.drop(
    columns=['id'], axis=1
).select_dtypes(
    exclude=['object']
).columns

cat_columns = market_file_data.select_dtypes(
    include=['object']
)

for column in numeric_columns:
    output_numeric(market_file_data, column)

for column in cat_columns:
    output_categorial(market_file_data, column)
# Out:
# count    1300.000000
# mean        4.253769
# std         1.014814
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64
# count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64
# count    1300.000000
# mean      601.898462
# std       249.856289
# min       110.000000
# 25%       405.500000
# 50%       606.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64
# count    1300.000000
# mean        0.319808
# std         0.249843
# min         0.000000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64
# count    1300.00000
# mean        3.27000
# std         1.35535
# min         1.00000
# ...

# %% [markdown]
# В поле тип сервиса есть записи с опечаткой, нужно исправить

# %%
market_file_data['тип_сервиса'] = market_file_data['тип_сервиса'].apply(
    lambda x: 'стандарт' if x == 'стандартт' else x
)

output_categorial(market_file_data, 'тип_сервиса')

# %%
numeric_columns = market_money_data.drop(
    columns=['id'], axis=1
).select_dtypes(
    exclude=['object']
).columns

cat_columns = market_money_data.select_dtypes(
    include=['object']
)

for column in numeric_columns:
    output_numeric(market_money_data, column)
    
for column in cat_columns:
    output_categorial(market_money_data, column)
# Out:
# count      3900.000000
# mean       5025.696051
# std        1777.704104
# min           0.000000
# 25%        4590.150000
# 50%        4957.500000
# 75%        5363.000000
# max      106862.200000
# Name: выручка, dtype: float64

# %% [markdown]
# В столбце "выручка" имеется выброс - значение более 100 тыс и аномальное значение, где выручка равна 0, стоит от них избавиться

# %%
market_money_data = market_money_data[
    (market_money_data['выручка'] < 100000) & 
    (market_money_data['выручка'] > 0)
]

# %%
output_numeric(market_money_data, 'выручка')
# Out:
# count    3893.000000
# mean     5007.282918
# std       679.724898
# min      2758.700000
# 25%      4592.000000
# 50%      4959.000000
# 75%      5363.000000
# max      7799.400000
# Name: выручка, dtype: float64

# %%
numeric_columns = market_time_data.drop(
    columns=['id'], axis=1
).select_dtypes(
    exclude=['object']
).columns

cat_columns = market_time_data.select_dtypes(
    include=['object']
)

for column in numeric_columns:
    output_numeric(market_time_data, column)
    
for column in cat_columns:
    output_categorial(market_time_data, column)
# Out:
# count    2600.000000
# mean       13.336154
# std         4.080198
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64

# %% [markdown]
# В двух таблицах в поле "период" были выявлены опечатки, которые следует исправить.

# %%
market_money_data['период'] = market_money_data['период'].apply(
    lambda x: 'предпредыдущий_месяц' if x == 'препредыдущий_месяц' else x
)

output_categorial(market_money_data, 'период')

# %%
market_time_data['период'] = market_time_data['период'].apply(
    lambda x: 'предыдущий_месяц' if x == 'предыдцщий_месяц' else x
)

output_categorial(market_time_data, 'период')

# %% [markdown]
# Опечатки исправлены, можно приступать к слиянию данных

# %% [markdown]
# ### Шаг 4. Объединение таблиц

# %% [markdown]
# Для начала следует преобразовать столбцы с периодом в отдельные

# %%
current_month_data = market_money_data[market_money_data['период'] == 'текущий_месяц']
last_month_data = market_money_data[market_money_data['период'] == 'предыдущий_месяц']
old_month_data = market_money_data[market_money_data['период'] == 'предпредыдущий_месяц']

current_month_agg_data = pd.pivot_table(
    current_month_data, 
    index='id', 
    values='выручка', 
    aggfunc='sum'
).reset_index().rename(columns={
    'выручка': 'выручка_текущий_месяц',
})

last_month_agg_data = pd.pivot_table(
    last_month_data, 
    index='id', 
    values='выручка', 
    aggfunc='sum'
).reset_index().rename(columns={
    'выручка': 'выручка_предыдущий_месяц',
})

old_month_agg_data = pd.pivot_table(
    old_month_data, 
    index='id', 
    values='выручка', 
    aggfunc='sum'
).reset_index().rename(columns={
    'выручка': 'выручка_предпредыдущий_месяц',
})

market_money_data = current_month_agg_data.merge(
    last_month_agg_data, on='id', how='outer'
).merge(
    old_month_agg_data, on='id', how='outer',
).dropna()
market_money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 1 to 1298
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1296 non-null   int64
#  1   выручка_текущий_месяц         1296 non-null   float64
#  2   выручка_предыдущий_месяц      1296 non-null   float64
#  3   выручка_предпредыдущий_месяц  1296 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 50.6 KB

# %%
current_month_data = market_time_data[market_time_data['период'] == 'текущий_месяц']
last_month_data = market_time_data[market_time_data['период'] == 'предыдущий_месяц']

current_month_agg_data = pd.pivot_table(
    current_month_data, 
    index='id', 
    values='минут', 
    aggfunc='sum'
).reset_index().rename(columns={
    'минут': 'минут_текущий_месяц',
})

last_month_agg_data = pd.pivot_table(
    last_month_data, 
    index='id', 
    values='минут', 
    aggfunc='sum'
).reset_index().rename(columns={
    'минут': 'минут_предыдущий_месяц',
})


market_time_data = current_month_agg_data.merge(last_month_agg_data, on='id', how='outer')
market_time_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1300 non-null   int64
#  1   минут_текущий_месяц     1300 non-null   int64
#  2   минут_предыдущий_месяц  1300 non-null   int64
# dtypes: int64(3)
# memory usage: 30.6 KB

# %%
full_data = market_file_data.merge(market_money_data, on='id')
full_data = full_data.merge(market_time_data, on='id')
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   покупательская_активность            1296 non-null   object
#  2   тип_сервиса                          1296 non-null   object
#  3   разрешить_сообщать                   1296 non-null   object
#  4   маркет_актив_6_мес                   1296 non-null   float64
#  5   маркет_актив_тек_мес                 1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   популярная_категория                 1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1296 non-null   int64
# ...

# %% [markdown]
# Объединение прошло успешно: не появилось лишних столбцов и не появилось пропусков

# %% [markdown]
# ### Шаг 5. Корреляционный анализ

# %% [markdown]
# Для оценки корреляций между признаками и проверки мультиколлинеарности необходимо построить корреляционную матрицу

# %%
full_data.drop(['id'], axis=1).phik_matrix(
    interval_cols=[
        'маркет_актив_6_мес', 
        'длительность', 
        'акционные_покупки', 
        'выручка_предпредыдущий_месяц',
        'выручка_предыдущий_месяц',
        'выручка_текущий_месяц'
    ]
)
# Out:
#                                      покупательская_активность  тип_сервиса  \
# покупательская_активность                             1.000000     0.129940
# тип_сервиса                                           0.129940     1.000000
# разрешить_сообщать                                    0.000000     0.289965
# маркет_актив_6_мес                                    0.544831     0.089911
# маркет_актив_тек_мес                                  0.000000     0.045258
# длительность                                          0.099901     0.401411
# акционные_покупки                                     0.506276     0.030010
# популярная_категория                                  0.299717     0.070809
# средний_просмотр_категорий_за_визит                   0.539607     0.185391
# неоплаченные_продукты_штук_квартал                    0.405041     0.113015
# ошибка_сервиса                                        0.224154     0.079515
# ...

# %% [markdown]
# Была обнаружена сильная корреляция между:
#
# 1) Выручками за прошлый и текущий месяц
#
# Также стоит отметить корреляции с целевым признаком:
#
# 1) Страниц за визит (0.74)
#
# 2) Минут предыдущий месяц (0.6)
#
# 3) Минут текущий месяц (0.56)
#
# Подозрений на мультиколлинеарность нет

# %% [markdown]
# ### Шаг 6. Использование пайплайнов

# %% [markdown]
# Для начала необходимо преобразовать отделить целевой признак от остальных и преобразовать его через LabelEncoder

# %%
X = full_data.drop(['покупательская_активность', 'id'], axis=1)
y = full_data['покупательская_активность']

display(X.head())
# Out:
#   тип_сервиса разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# 0     премиум                 да                 4.4                     4
# 1    стандарт                нет                 4.9                     3
# 2    стандарт                 да                 3.2                     5
# 3    стандарт                нет                 5.1                     3
# 4    стандарт                 да                 3.3                     4
#
#    длительность  акционные_покупки популярная_категория  \
# 0           819               0.75     Товары для детей
# 1           539               0.14    Домашний текстиль
# 2           896               0.99     Товары для детей
# 3          1064               0.94     Товары для детей
# 4           762               0.26    Домашний текстиль
#
#    средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 0                                    4                                   4
# ...

# %% [markdown]
# Далее нужно разделить данные на обучающую и тестовую выборки

# %%
RANDOM_STATE = 42

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

encoder = LabelEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

X_train.info()

labels_dict = {index: value for index, value in enumerate(encoder.classes_)}
print(labels_dict)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1036 entries, 532 to 511
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   тип_сервиса                          1036 non-null   object
#  1   разрешить_сообщать                   1036 non-null   object
#  2   маркет_актив_6_мес                   1036 non-null   float64
#  3   маркет_актив_тек_мес                 1036 non-null   int64
#  4   длительность                         1036 non-null   int64
#  5   акционные_покупки                    1036 non-null   float64
#  6   популярная_категория                 1036 non-null   object
#  7   средний_просмотр_категорий_за_визит  1036 non-null   int64
#  8   неоплаченные_продукты_штук_квартал   1036 non-null   int64
#  9   ошибка_сервиса                       1036 non-null   int64
#  10  страниц_за_визит                     1036 non-null   int64
# ...

# %% [markdown]
# Далее необходимо создать пайплайн для подготовки данных и словарь параметров для тестирования моделей. Для признака "популярная_категория" был выбран OrdinalEncoder: несмотря на то, что он не является порядковым - лучше использовать его, чтобы не создавать много лишних столбцов. Для остальных категориальных столбцов использовался OneHotEncoder.
#
# После чего необходимо сформировать полный пайплайн, чтобы обучить и проверить все модели, в качестве метрики оценки качества модели была выбрана ROC-AUC, т.к. важно определять оба класса без каких-то предпочтений (для магазина критично знать, когда рост покупательской активности, а когда падение)

# %%
ohe_columns = ['популярная_категория',]
ord_columns = ['тип_сервиса', 'разрешить_сообщать',]
num_columns = [
    'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
    'акционные_покупки', 'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 
    'страниц_за_визит', 'выручка_предпредыдущий_месяц', 
    'выручка_предыдущий_месяц', 'выручка_текущий_месяц',
    'минут_текущий_месяц', 'минут_предыдущий_месяц',
]

ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(
                missing_values=np.nan, 
                strategy='most_frequent'
            )
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'],
                    ['нет', 'да'],
                ], 
                handle_unknown='use_encoded_value', 
                unknown_value=np.nan,
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(
                missing_values=np.nan, 
                strategy='most_frequent'
            )
        ),
    ]
)

data_preprocessor = ColumnTransformer([
    ('ohe', OneHotEncoder(sparse=False, handle_unknown='ignore', drop='first'), ohe_columns),
    ('ord', ord_pipe, ord_columns),
    ('num', StandardScaler(), num_columns),
], remainder='passthrough')

# %%
pipeline = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', KNeighborsClassifier())
])

param_grid = [
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 111),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'models__kernel': ['linear', 'rbf', 'precomputed'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 10),
        'models__min_samples_split': range(2, 10),
        'models__min_samples_leaf': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
    },
    {
        'models': [DummyClassifier()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
    }
]

# %%
randomized_search = RandomizedSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1,
)

# %%
randomized_search.fit(X_train, y_train)

print(f'Лучшая модель и ее параметры: {randomized_search.best_estimator_}')
print(f'ROC_AUC лучшей модели на кросс-валидации: {randomized_search.best_score_}')
# Out:
# Лучшая модель и ее параметры: Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ord',
#                                                                    OrdinalEncoder(categories=[['стандарт',
# ...

# %%
predictions = randomized_search.predict_proba(X_test)[:,1]
print(f'ROC_AUC лучшей модели на тестовой выборке: {roc_auc_score(y_test, predictions)}')
# Out:
# ROC_AUC лучшей модели на тестовой выборке: 0.873172720998808

# %%
dummy = DummyClassifier()

dummy.fit(X_train, y_train)

predictions = dummy.predict_proba(X_test)[:,1]
print(f'ROC_AUC лучшей модели на тестовой выборке: {roc_auc_score(y_test, predictions)}')
# Out:
# ROC_AUC лучшей модели на тестовой выборке: 0.5

# %% [markdown]
# Результат лучше, чем у dummy-модели

# %% [markdown]
# Самой эффективной себя показала модель DecisionTreeClassifier с max_depth=7, min_samples_leaf=8 и min_samples_split=6 (Не отобразилось, потому что это значение по-умолчанию) с использованием скейлера StandardScaler()

# %% [markdown]
# ### Шаг 7. Анализ важности признаков

# %% [markdown]
# Для оценки важности признаков будет использована библиотека shap

# %%
rs_steps = randomized_search.best_estimator_.named_steps

preprocessor = rs_steps['preprocessor']
model = rs_steps['models']

X_train_preprocessed = preprocessor.transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)

ohe_columns_preprocessed = preprocessor.named_transformers_['ohe'].get_feature_names_out(
    input_features=ohe_columns
)

all_columns = np.concatenate([ord_columns, num_columns, ohe_columns_preprocessed])

X_train_preprocessed = pd.DataFrame(X_train_preprocessed, columns=all_columns)
X_test_preprocessed = pd.DataFrame(X_test_preprocessed, columns=all_columns)

explainer = shap.Explainer(model.predict, X_train_preprocessed)
shap_values = explainer.shap_values(X_train_preprocessed)

plt.title('Анализ важности признаков')
plt.xlabel('Показатель важности')
plt.ylabel('Наименование признака')
shap.summary_plot(shap_values, X_test_preprocessed, plot_type='bar')
# Out:
# C:\Users\vault\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\vault\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\vault\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\vault\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\vault\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ...

# %% [markdown]
# Итого: самые значимые признаки - это:
#
#     1) Категории: товары для детей, домашний текстиль, техника для красоты и здоровья
#
#     2) Выручки за все месяцы
#
#     3) Проведенные минуты
#
# В качестве совета можно дать проводить больше акций по указанным категориям в магазине и работать над удержанием пользователя на сайте

# %% [markdown]
# ### Шаг 8. Сегментация покупателей

# %% [markdown]
# Далее необходимо провести сегментацию покупателей на основе данных работы модели: для этого необходимо выполнить слияние таблиц со всеми данными и таблицы с прибыльностью

# %%
full_data = full_data.merge(money_data, on='id')
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   покупательская_активность            1296 non-null   object
#  2   тип_сервиса                          1296 non-null   object
#  3   разрешить_сообщать                   1296 non-null   object
#  4   маркет_актив_6_мес                   1296 non-null   float64
#  5   маркет_актив_тек_мес                 1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   популярная_категория                 1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1296 non-null   int64
# ...

# %% [markdown]
# Лишних столбцов и пустых значений не появилось, значит слияние произошло правильно, далее необходимо получить прогнозы покупательской активности

# %%
model = randomized_search.best_estimator_
full_data['predict'] = model.predict_proba(full_data.drop(['id', 'покупательская_активность', 'прибыль'], axis=1))[:,1]
full_data.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# Отделим покупателей с вероятной низкой покупательской активностью

# %%
full_data = full_data[full_data['predict'] >= 0.7]
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388 entries, 0 to 1285
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   388 non-null    int64
#  1   покупательская_активность            388 non-null    object
#  2   тип_сервиса                          388 non-null    object
#  3   разрешить_сообщать                   388 non-null    object
#  4   маркет_актив_6_мес                   388 non-null    float64
#  5   маркет_актив_тек_мес                 388 non-null    int64
#  6   длительность                         388 non-null    int64
#  7   акционные_покупки                    388 non-null    float64
#  8   популярная_категория                 388 non-null    object
#  9   средний_просмотр_категорий_за_визит  388 non-null    int64
#  10  неоплаченные_продукты_штук_квартал   388 non-null    int64
# ...

# %% [markdown]
# Далее оценим значимые признаки из прошлого пункта + оцним прибыль от этих пользователей

# %%
important_columns = [
    'страниц_за_визит', 'выручка_предпредыдущий_месяц', 'минут_предыдущий_месяц',
    'минут_текущий_месяц', 'маркет_актив_6_мес',
    'акционные_покупки'
]

for column in important_columns:
    output_numeric(full_data, column)
output_numeric(full_data, 'прибыль')
# Out:
# count    388.000000
# mean       4.515464
# std        2.438339
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.250000
# max       15.000000
# Name: страниц_за_визит, dtype: float64
# count     388.000000
# mean     4618.314433
# std       256.336683
# min      4098.000000
# 25%      4440.500000
# 50%      4615.000000
# 75%      4777.250000
# max      5555.000000
# Name: выручка_предпредыдущий_месяц, dtype: float64
# count    388.000000
# mean       9.922680
# std        2.771058
# min        5.000000
# 25%        8.000000
# 50%       10.000000
# 75%       11.000000
# max       21.000000
# Name: минут_предыдущий_месяц, dtype: float64
# count    388.000000
# mean      10.507732
# std        3.089942
# min        4.000000
# 25%        9.000000
# 50%       10.000000
# 75%       12.000000
# max       22.000000
# Name: минут_текущий_месяц, dtype: float64
# count    388.000000
# mean       3.630928
# std        1.020322
# min        0.900000
# ...

# %% [markdown]
# Из графиков видно следующее:
# 1) Пользователи делали мало акционных покупок от общего числа покупок (есть разрыв) + пик приходится на диапазон от 0.2 до 0.4
#
# 2) Пользователи из этого сегмента просматривает малое количество страниц за визит

# %% [markdown]
# По итогу можно дать следующие рекомендации по работе с таким сегментом:
#
#     1) Работать над удержанием внимания пользователя на сайте
#
#     2) Выделить те, категории, которые пользователи из этого сегмента часто просматривают и делать по ним акции

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе работы было проделано следующее:
#
#     1) При предобработке были удалены дубликаты, очищены записи с выбросами
#
#     2) При исследовании данных были выявлены опечатки в данных, выбросы и аномалии, которые были очищены
#
#     3) Было обучено несколько моделей, среди которых была выбрана модель DecisionTreeClassifier с max_depth=8, min_samples_leaf=8 и min_samples_split=2 (Не отобразилось, потому что это значение по-умолчанию) с использованием скейлера StandardScaler(). Для оценки использовалась метрика ROC_AUC, значение которой было 0.88 на тестовых данных
#
#     4) Было выявлено, что больше всего на модель влияют следующие признаки:
#
#         4.1) Категории: товары для детей, домашний текстиль, техника для красоты и здоровья
#
#         4.2) Выручки за все месяцы
#
#         4.3) Проведенные минуты
#
#     5) Рекомендация менеджменту магазина: проводить больше акций по указанным категориям в магазине и работать над удержанием пользователя на сайте
